# %%
from experiment import run_experiment

# %%
# GD likely got caught in a local minimum here.

results = run_experiment(
    # Architecture
    architecture = 'fc',
    architecture_params = {'hidden_sizes': [16, 16]},
    
    # Dataset
    dataset = 'cifar10',
    subset_size = 5000,
    seed = 12,
    
    # Model configuration
    activation ='relu',
    loss_type = 'mse',
    init_method = 'uniform',
    
    # Training parameters
    optimizer_type='gd',
    learning_rate=0.08,
    batch_size = None,
    max_iterations = 5000,
    
    # Analysis parameters
    n_eigenvalues=3
)
# Out:
# Using device: mps
# Starting training...
# Iteration 1/5000, loss: 0.102845, top eigenvalue: 1.054274
# Iteration 2/5000, loss: 0.102037, top eigenvalue: 1.037651
# Iteration 3/5000, loss: 0.101307, top eigenvalue: 1.021153
# Iteration 4/5000, loss: 0.100645, top eigenvalue: 1.006364
# Iteration 5/5000, loss: 0.100044, top eigenvalue: 0.992852
# Iteration 6/5000, loss: 0.099494, top eigenvalue: 0.980743
# Iteration 7/5000, loss: 0.098990, top eigenvalue: 0.969436
# Iteration 8/5000, loss: 0.098527, top eigenvalue: 0.958145
# Iteration 9/5000, loss: 0.098099, top eigenvalue: 0.948493
# Iteration 10/5000, loss: 0.097704, top eigenvalue: 0.938991
# Iteration 11/5000, loss: 0.097338, top eigenvalue: 0.929588
# Iteration 12/5000, loss: 0.096998, top eigenvalue: 0.921928
# Iteration 13/5000, loss: 0.096681, top eigenvalue: 0.914620
# Iteration 14/5000, loss: 0.096386, top eigenvalue: 0.907822
# Iteration 15/5000, loss: 0.096110, top eigenvalue: 0.901520
# ...
