# %%
from experiment import run_experiment

# %%
results = run_experiment(
    # Architecture
    architecture = 'fc',
    architecture_params = {'hidden_sizes': [16, 16]},
    
    # Dataset
    dataset = 'mnist',
    subset_size = 2000,
    seed = 4,
    
    # Model configuration
    activation ='relu',
    loss_type = 'mse',
    init_method = 'uniform',
    
    # Training parameters
    optimizer_type='gd',
    learning_rate=0.08,
    batch_size = None,
    max_iterations = 250,
    
    # Analysis parameters
    n_eigenvalues=3
)
# Out:
# Using device: mps
# Starting training...
# Iteration 1/250, loss: 0.099591, top eigenvalue: 0.432944
# Iteration 2/250, loss: 0.099171, top eigenvalue: 0.428413
# Iteration 3/250, loss: 0.098767, top eigenvalue: 0.424342
# Iteration 4/250, loss: 0.098379, top eigenvalue: 0.421286
# Iteration 5/250, loss: 0.098006, top eigenvalue: 0.418350
# Iteration 6/250, loss: 0.097646, top eigenvalue: 0.415846
# Iteration 7/250, loss: 0.097301, top eigenvalue: 0.413375
# Iteration 8/250, loss: 0.096968, top eigenvalue: 0.411533
